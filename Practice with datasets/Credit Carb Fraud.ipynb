# %% [markdown]
# Importing Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# Importing Data

# %%
credit_card_data = pd.read_csv('/content/drive/MyDrive/ML Data Files/creditcard.csv')

credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.shape
# Out:
# (284807, 31)

# %%
# dataset information
credit_card_data.info()

# %%
credit_card_data.isnull().sum()

# %%
# credit_card_data = credit_card_data.dropna()
# credit_card_data.isnull().sum()

# %%
# distribution of legit transaction and fraudulant transaction
credit_card_data['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# This Dataset is Highly Unbalanced
#
# 0---> Normal Transaction
# 1---> Fraudulant Transaction

# %%
# seperating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
fraud.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    80746.806911   -4.771948    3.623778   -7.033281    4.542029
# std     47835.365138    6.783687    4.291216    7.110937    2.873318
# min       406.000000  -30.552380   -8.402154  -31.103685   -1.313275
# 25%     41241.500000   -6.036063    1.188226   -8.643489    2.373050
# 50%     75568.500000   -2.342497    2.717869   -5.075257    4.177147
# 75%    128483.000000   -0.419200    4.971257   -2.276185    6.348729
# max    170348.000000    2.132386   22.057729    2.250210   12.114672
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -3.151225   -1.397737   -5.568731    0.570636   -2.581123  ...
# std      5.372468    1.858124    7.206773    6.797831    2.500896  ...
# ...

# %%
# compare the values for both transactions
# grouping the 'Class' column by the mean values of all the columns
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling
#
# Build a sample dataset containing similiar distribution of normal and Fraudulent Transactions
#
# Number of Fraudulent Transactions --> 492

# %%
legit_sample = legit.sample(n=492)
legit_sample.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 184705  126352.0 -0.686363  0.666738  0.861579 -0.858765  0.769492 -0.137483
# 100099   67414.0 -1.515062 -1.413257  3.341566 -1.213866 -0.255960  0.291201
# 65780    51742.0  1.375253 -1.124108 -0.438834 -1.592065 -0.768433 -0.449088
# 6582      8018.0 -0.616347  1.304872  0.646657  0.969711  0.176297 -0.116708
# 143115   85127.0 -2.002555  2.103537 -0.723020  0.634979 -1.126043 -0.900264
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 184705  0.916960  0.059721 -0.565475  ... -0.259866 -0.886316 -0.102996
# 100099 -1.369744  0.412984  0.157707  ...  0.248510  0.996118 -0.348300
# 65780  -0.440524 -0.225406 -2.453345  ... -0.447534 -1.186055 -0.057034
# 6582    0.764228  0.110537  0.240484  ...  0.064172  0.281819 -0.015543
# 143115 -0.804909  1.171322 -0.413187  ...  0.152428 -0.089944  0.674030
#
# ...

# %% [markdown]
# Concatenating two Dataframes

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)
new_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 184705  126352.0 -0.686363  0.666738  0.861579 -0.858765  0.769492 -0.137483
# 100099   67414.0 -1.515062 -1.413257  3.341566 -1.213866 -0.255960  0.291201
# 65780    51742.0  1.375253 -1.124108 -0.438834 -1.592065 -0.768433 -0.449088
# 6582      8018.0 -0.616347  1.304872  0.646657  0.969711  0.176297 -0.116708
# 143115   85127.0 -2.002555  2.103537 -0.723020  0.634979 -1.126043 -0.900264
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 184705  0.916960  0.059721 -0.565475  ... -0.259866 -0.886316 -0.102996
# 100099 -1.369744  0.412984  0.157707  ...  0.248510  0.996118 -0.348300
# 65780  -0.440524 -0.225406 -2.453345  ... -0.447534 -1.186055 -0.057034
# 6582    0.764228  0.110537  0.240484  ...  0.064172  0.281819 -0.015543
# 143115 -0.804909  1.171322 -0.413187  ...  0.152428 -0.089944  0.674030
#
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      89516.827236 -0.079426 -0.011525  0.141971 -0.044293 -0.024011
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.136256  0.006590 -0.047742 -0.008372  ... -0.010198  0.038761
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.001704 -0.016715 -0.009337  0.007375  0.015347  0.012899 -0.012549
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       98.194451
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features and Targets

# %%
X = new_dataset.drop(columns='Class',axis=1)
Y = new_dataset['Class']

# %%
print(X)
print(Y)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 184705  126352.0 -0.686363  0.666738  0.861579 -0.858765  0.769492 -0.137483
# 100099   67414.0 -1.515062 -1.413257  3.341566 -1.213866 -0.255960  0.291201
# 65780    51742.0  1.375253 -1.124108 -0.438834 -1.592065 -0.768433 -0.449088
# 6582      8018.0 -0.616347  1.304872  0.646657  0.969711  0.176297 -0.116708
# 143115   85127.0 -2.002555  2.103537 -0.723020  0.634979 -1.126043 -0.900264
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# Splitting the Data into Training Data & Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

print(X.shape, X_train.shape, X_test.shape, Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (984, 30) (787, 30) (197, 30) (984,) (787,) (197,)

# %% [markdown]
# Model Training

# %%
model = LogisticRegression()
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Evaluation

# %%
# accuracy score Training data
X_train_pred = model.predict(X_train)
training_accuracy = accuracy_score(X_train_pred, Y_train)

print('Training data Accuracy score : ', training_accuracy)
# Out:
# Training data Accuracy score :  0.9428208386277002

# %%
# accuracy score test data
X_test_pred = model.predict(X_test)
test_accuracy = accuracy_score(X_test_pred, Y_test)

print('Test data Accuracy score : ', test_accuracy)
# Out:
# Test data Accuracy score :  0.9238578680203046
