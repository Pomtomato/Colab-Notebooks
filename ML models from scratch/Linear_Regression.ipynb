# %%
# Importing libraries
import numpy as np
import pandas as pd
from sklearn.datasets import make_regression
from sklearn.datasets import make_sparse_uncorrelated
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from matplotlib import style
from matplotlib import axes as ax
import seaborn as sns

# %%
# Set the figure size
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

# Creating and plotting the regression problem
style.use("Solarize_Light2")

r_data, r_values = make_regression(n_samples=500, n_features=2, n_informative=1, noise=10)

# %%
# Creating the regression problem with sparse uncorrelated design
x, y = make_sparse_uncorrelated(n_samples=500, n_features=4)

# %%
# Plotting the dataset
style.use("Solarize_Light2")
plt.figure(figsize=(7.50, 3.50))
plt.title("Random regression problem with sparse uncorrelated design", fontsize="12")
plt.scatter(x[:,1],y,edgecolor="k");
plt.show()

# %%
plt.scatter(r_data[:,1],r_values,cmap='rocket');
plt.show()
# Out:
# <ipython-input-5-c439253b2c88>:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(r_data[:,1],r_values,cmap='rocket');

# %%
x.shape[1]
x.shape
# Out:
# (500, 4)

# %%
class LinearRegression:

  def __init__(self, train_data):
    self.weights = np.array([np.random.uniform(-1,1) for _ in range(train_data.shape[1])], ndmin=1)
    self.bias = np.random.uniform(-1,1)
    # self.train_data = train_data
    # self.train_label = train_label
    # self.predictions = np.zeros(train_label.shape)
    # self.backward_ = lambda:None
    # self.grad = 0.0

  def forward_prop(self, train_data):
    return np.matmul(train_data , self.weights.T) + self.bias

  def cost_function(self, train_label, predictions):
    return np.mean((train_label - predictions)**2)

  def back_prop(self, train_data, predictions, train_label):
    do/dw = np.mean(train_data.T * (predictions - train_label))

# %%
class LinearRegression:

  def __init__(self, learning_rate=0.01, iterations=100):
    self.lr = learning_rate
    self.iter = iterations
    self.cost = 0

  def fit(self, X, Y):
    self.m , self.n = x.shape
    self.x = X
    self.y = Y
    self.b = np.random.uniform(-1,1)
    self.w = np.array([np.random.uniform(-1,1) for _ in range(self.n)], ndmin =1)

    for i in range(1, self.iter + 1):
      self.update_weights()
      print(f"Iteration {i}|| RMSE {self.cost}")
      #True {self.y}|| Predicted {self.y_pred}||

    return self

  def update_weights(self):
    y_pred = self.predict(self.x)

    self.cost = self.rmse(self.y, y_pred)

    # gradient calculation
    dw = (-2 * (self.x.T).dot((self.y - y_pred)))/self.m
    db = (-2 * np.sum((self.y - y_pred)))/self.m

    # update weights and bias
    self.w -= self.lr * dw
    self.b -= self.lr * db

    return self

  def test(self, y_t, y_p):
    return self.rmse(y_t, y_p)

  def predict(self, X):
    return X.dot(self.w) + self.b

  def rmse(self, y, y_p):
    m = y.shape
    return np.sqrt(np.sum(((y - y_p)**2))/m)

# driver code
def main():
  #x, y = make_regression(n_samples=500, n_features=4)
  df1 = pd.read_csv("/content/sample_data/california_housing_train.csv")
  df2 = pd.read_csv("/content/sample_data/california_housing_test.csv")

  df = pd.concat([df1, df2])
  x = df.drop(["median_house_value"], axis=1)
  y = df["median_house_value"]
  x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

  model = LinearRegression()
  model.fit(x_train, y_train)

  y_pred = model.predict(x_test)
  tt = model.test(y_test, y_pred)

  print(tt)
  #print(f"Iteration {model.i}|| True {model.y}|| Predicted {model.y_pred}|| RMSE {model.cost}")
  # y_pred = model.predict(x_test)
  # rmse = model.rmse(y_test)

  # print(f"True {}")

# %%
if __name__ == "__main__":
  main()
# Out:
# Iteration 1|| RMSE 213181.1307028404
# Iteration 2|| RMSE 38111926167.70975
# Iteration 3|| RMSE 9482986704891010.0
# Iteration 4|| RMSE 2.3595535539585965e+21
# Iteration 5|| RMSE 5.871033197941641e+26
# Iteration 6|| RMSE 1.4608285009471013e+32
# Iteration 7|| RMSE 3.6348285510079096e+37
# Iteration 8|| RMSE 9.044168146128391e+42
# Iteration 9|| RMSE 2.2503668689617227e+48
# Iteration 10|| RMSE 5.5993552564460426e+53
# Iteration 11|| RMSE 1.3932296871378813e+59
# Iteration 12|| RMSE 3.466629410390981e+64
# Iteration 13|| RMSE 8.62565561151325e+69
# Iteration 14|| RMSE 2.1462327211964282e+75
# Iteration 15|| RMSE 5.340249021055122e+80
# Iteration 16|| RMSE 1.3287589610031912e+86
# Iteration 17|| RMSE 3.306213566979755e+91
# Iteration 18|| RMSE 8.226509450764673e+96
# Iteration 19|| RMSE 2.0469173080474165e+102
# Iteration 20|| RMSE 5.093132744890513e+107
# Iteration 21|| RMSE 1.2672715724808887e+113
# Iteration 22|| RMSE 3.1532208541576263e+118
# ...

# %%
a = np.array([np.random.uniform(-1,1) for _ in range(4)],ndmin =1)

a.shape
a
# Out:
# array([-0.16760485, -0.99030746,  0.46294936, -0.16395244])

# %%
p = np.zeros(4)
print(p)
p.shape
# Out:
# [0. 0. 0. 0.]
# (4,)

# %%
y = np.array([3., 3., 4., 1., 5.])
y_pred = np.array([2.3, 3.1, 4.5, 1.9, 5.2])
y, y_pred.shape

a = np.sqrt(np.mean(((y - y_pred)**2)))
a
# Out:
# 0.565685424949238

# %%
df1 = pd.read_csv("/content/sample_data/california_housing_train.csv")
df2 = pd.read_csv("/content/sample_data/california_housing_test.csv")

df = pd.concat([df1, df2])
x = df.drop(["median_house_value"], axis=1)
y = df["median_house_value"]
x
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -114.31     34.19                15.0       5612.0          1283.0
# 1       -114.47     34.40                19.0       7650.0          1901.0
# 2       -114.56     33.69                17.0        720.0           174.0
# 3       -114.57     33.64                14.0       1501.0           337.0
# 4       -114.57     33.57                20.0       1454.0           326.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income
# ...
