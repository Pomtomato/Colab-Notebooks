# %%
import matplotlib.pyplot as plt
import numpy as np

alpha = np.logspace(-4, -0.5, 30)
print(alpha.size)
# Out:
# 30

# %%
plt.figure(figsize=(8,8))
plt.semilogx(range(0,30,1), alpha)

# %%
test_scores = [0.74821666,0.80089016,0.92876979,0.95540287,0.89083901,0.90926355,0.82520379]
test_len = [24377, 9983, 9631, 7453, 5319, 5293, 4156]
avg=[]
for i in range(0,7):
  avg.append(test_scores[i]/test_len[i])

np.sum(avg)
# Out:
# 0.000873370458588845
